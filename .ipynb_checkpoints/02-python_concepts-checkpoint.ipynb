# %% [markdown]
# ### Python Programming Concepts

# %% [markdown]
# #### 1. Create a variable to store the value 500 for sales

# %%
sales = 600
sales
# Out:
# 600

# %% [markdown]
# #### 2. Create a variable to store several values:
# * sales: 500, 475, 625
# * integers 1 - 9

# %%
sales = [500, 475, 625]
sales.pop()
# Out:
# 625

# %%
integers = list(range(10,1,-1))
integers
# Out:
# [10, 9, 8, 7, 6, 5, 4, 3, 2]

# %% [markdown]
# #### 3. Create a variable to store the names and email addresses for a number of customers
# * John, john@some.com; Ann, ann@some.com

# %%
Names = ["John", "Ann"]
emailaddresses = ["ann@some.com","john@some.com"]
Names,emailaddresses
# Out:
# (['John', 'Ann'], ['ann@some.com', 'john@some.com'])

# %% [markdown]
# #### 4. Use Python to generate a random value based on each of following:
# 1. between 0 and 1
# 2. the standard normal distribution (rounded to two decimal places)
# 3. a value between 1 and 10
# 4. either H or T

# %%
import random
value = random.random()
value_normaldis=round(random.gauss(0,1),2)
value_110 = random.randint(1,10)
value_coin = random.choice(['H', 'T'])
value_coin,value_110,value_normaldis
# Out:
# ('H', 9, 0.66, 0.42784759244371384)

# %% [markdown]
# #### 5. Use Python to determine your current working directory

# %%
import os
current_path = os.getcwd()
current_path
# Out:
# 'C:\\Users\\zwei2\\Downloads'

# %% [markdown]
# #### 6. Use Python to determine how many days until New Year's Day

# %%
import datetime
today=datetime.date.today()
Newyearday=datetime.date(2027,1,1)
daysuntil=Newyearday-today
daysuntil
# Out:
# datetime.timedelta(days=339)

# %% [markdown]
# #### 7. Write a short program that displays the future value of 1,000 earning 5%  at the end of each year for the next 5 years

# %%
amount=1000
rate=0.05
for year in range (1,6):
    amount= amount*(1+rate)
    print(amount)
# Out:
# 1050.0
# 1102.5
# 1157.625
# 1215.5062500000001
# 1276.2815625000003

# %% [markdown]
# #### 8. Write a short program that prompts a user to enter a stock symbol and press enter. Add each symbol entered to a variable. The program should run until the user presses the enter key without entering anything (empty string)

# %%
symbol=[]
while True:
    user_input= input("enter a stock symbol:")
    if user_input =="":
        break
# Out:
# enter a stock symbol: sasd
# enter a stock symbol: asdsda
# enter a stock symbol:

# %% [markdown]
# #### 9. Write the code necessary to calculate the sum of the square differences of a group of values :
# 58, 32, 37, 41, 36, 36, 54, 37, 25, 53
# ##### $\Sigma $(${x}$ - $\bar{x}$)$^2$

# %%
sumsquare=0
values=[58, 32, 37, 41, 36, 36, 54, 37, 25, 53]
mean= sum(values)/len(values)
for num in values:
    diff=num-mean
    sumsquare=sumsquare+diff**2
sumsquare
# Out:
# 1020.9000000000001

# %% [markdown]
# #### 10. Opening, reading and writing files

# %%
with open('', 'r') as f:
    content = f.read()
with open('', 'w') as f:
    f.write()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 with open('', 'r') as f:
#       2     content = f.read()
#       3 with open('', 'w') as f:
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: ''

# %% [markdown]
# #### 11. Create a function the will simulate rolling two die and return the value of each and and the sum

# %%
import random
die1 = random.randint(1,6)
die2 = random.randint(1,6)
sum1 = die1+die2
die1,die2,sum1
# Out:
# (5, 2, 7)

# %% [markdown]
# #### 12. Write the code needed to evaluate whether a value in a group of values is negative or postive and prints an approriate message, i.e. postive, negative
# -1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2

# %%
value=[-1.59, 2.36, 1.69, 1.13, -0.91, 1.48, -0.34, 1.31, -0.74, 0.2]
for x in value:
    if x < 0:
        print("negative")
    if x > 0:
        print("positive")
    else:
        print("0")
# Out:
# negative
# 0
# positive
# positive
# positive
# negative
# 0
# positive
# negative
# 0
# positive
# negative
# 0
# positive

# %% [markdown]
# #### 14.  Complete the following:
# 1. Write a program that generates 500 random integers from 1 to n, for example, the first integer will be 1 the second will be 1 or 2, the fifth between 1 and 5, and so on.
# 2. The program should write each integer to a file
# 3. Once all integers are written close the file
#
# ##### Part 2
# 1. Open and read the file into a list
# 2. Create a line plot of the data

# %%
import random
import matplotlib.pyplot as plt
with open('num.txt', 'w') as f:
    for n in range(1,500):
        num = random.randint(1,n)
        f.write(str(num)+"\n")
data=[]
with open('num.txt', 'r') as f:
    for line in f:
        data.append(int(line.strip()))
plt.plot(data)
plt.show()
